# %%
for i in range(11,1)
# Out:
#   Cell In[4], line 1
#     for i in range(11,1)
#                         ^
# SyntaxError: expected ':'

# %%
for i in range(11,1):
    print(i)

# %%
for i in range(11,1):
    print(i)

# %%
for i in range(11,0,-1):
    print(i,"L")
# Out:
# 11 L
# 10 L
# 9 L
# 8 L
# 7 L
# 6 L
# 5 L
# 4 L
# 3 L
# 2 L
# 1 L
